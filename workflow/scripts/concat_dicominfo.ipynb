# %%
import pandas as pd
from pathlib import Path

# %%
# point this to your BIDS_OUT
bids_out = Path("/media/jpmcgeown/PortableSSD/test_heudiconv_bids")

all_tsvs = list(bids_out.glob(".heudiconv/*/info/*.tsv"))

# %%
print(f"Found {len(all_tsvs)} dicominfo.tsv files")
for t in all_tsvs:
    print(t)
# Out:
# Found 3 dicominfo.tsv files
# /media/jpmcgeown/PortableSSD/test_heudiconv_bids/.heudiconv/Conc_20Ntb14_Control_200/info/dicominfo_ses-A.tsv
# /media/jpmcgeown/PortableSSD/test_heudiconv_bids/.heudiconv/Conc_20Ntb14_Rugby_204/info/dicominfo_ses-B.tsv
# /media/jpmcgeown/PortableSSD/test_heudiconv_bids/.heudiconv/Conc_20Ntb14_Rugby_51/info/dicominfo_ses-A.tsv
